# %%
csv_files = r"C:\Users\kayer\OneDrive\Desktop\COMPROGLAB_Rivera\ComProg_Lab7\spotify_top_1000_tracks.csv"
df = pd.read_csv(csv_files)

# %% [markdown]
# # Safe Plotting with Try-Except Blocks

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

try:
    sns.barplot(x='category', y='value', data=df)
    plt.title('Bar Plot Example')
    plt.show()

except KeyError as e:
    print(f"Column not found: {e}")

except ValueError as e:
    print(f"Value error during plotting: {e}")

except Exception as e:
    print(f"Unexpected error: {e}")
# Out:
# Value error during plotting: Could not interpret value `category` for `x`. An entry with this name does not appear in `data`.

# %% [markdown]
# # Validate and Clean Data Before Plotting

# %%
if 'category' in df.columns and pd.api.types.is_numeric_dtype(df['value']):
 df_clean = df.dropna(subset=['category', 'value'])
 sns.boxplot(x='category', y='value', data=df_clean)
 plt.show()
else:
 print("Check column names or data types before plotting.")
# Out:
# Check column names or data types before plotting.

# %% [markdown]
# # Handle Large Datasets Efficiently

# %%
df_sample = df.sample(500)
print(df_sample.columns)
sns.scatterplot(x='duration_min', y='popularity', data=df_sample)
plt.show()
# Out:
# Index(['track_name', 'artist', 'album', 'release_date', 'popularity',
#        'spotify_url', 'id', 'duration_min'],
#       dtype='str')

# %% [markdown]
# # Customize Plots Wisely

# %%
# 1. Define Student Metadata
student_name = "Kaye Celene G. Rivera" 
student_id = "5870"

# 2. Setup the visual space
plt.figure(figsize=(14, 7)) # Wider for better artist name spacing

# 3. Create the boxplot using the Top 20 rows of your cleaned data
# We use artist and popularity to match your Spotify dataset
sns.boxplot(
    x='artist', 
    y='popularity', 
    data=df_clean.head(20),
    palette=['#8C1515', '#888888', '#1598C1']
)

# 4. Apply "Wise Customizations" (Clarity and Identification)
plt.title(f"Student: {student_name} ({student_id})\nTop 20 Artists: Popularity Distribution Analysis", fontsize=14)
plt.xlabel('Artist Name', fontsize=12)
plt.ylabel('Popularity Score (0-100)', fontsize=12)

# 5. Fix the "Smudge": Rotate artist names and align them to the right
plt.xticks(rotation=45, ha='right')

# 6. Add subtle gridlines for readability (PDF Point #3)
plt.grid(True, linestyle='--', alpha=0.3)

plt.show()
# Out:
# C:\Users\kayer\AppData\Local\Temp\ipykernel_22204\4086929991.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\kayer\AppData\Local\Temp\ipykernel_22204\4086929991.py:10: UserWarning:
# The palette list has fewer values (3) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(
